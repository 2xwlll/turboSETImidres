# %%
from blimpy import Waterfall

wf = Waterfall(
    "/datag/public/voyager_2020/spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_59046_80036_DIAG_VOYAGER-1_0011.rawspec.0002.h5",
    load_data=False,
)

print("shape =", wf.container.selection_shape)
print("nchans =", wf.header.get("nchans"))
print("nfpc =", wf.header.get("nfpc"))
print("foff =", wf.header.get("foff"))
# Out:
# shape = (279, 1, 1155072)
# nchans = 1155072
# nfpc = None
# foff = -0.00286102294921875

# %%
from blimpy import Waterfall

wf = Waterfall(
    "/datag/public/voyager_2020/spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_59046_80036_DIAG_VOYAGER-1_0011.rawspec.0002.h5",
    load_data=False
)

print("shape:", wf.container.selection_shape)
print("nchans:", wf.header.get("nchans"))
print("nfpc:", wf.header.get("nfpc"))
print("foff:", wf.header.get("foff"))
# Out:
# shape: (279, 1, 1155072)
# nchans: 1155072
# nfpc: None
# foff: -0.00286102294921875
